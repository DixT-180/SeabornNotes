# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style = 'darkgrid')

# %%
tips=sns.load_dataset('tips')#seaborn library has default datasets # it loads dataset into dataframe

# %%
sns.relplot(x='total_bill',y='tip',data = tips) #facet grid

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',hue = 'smoker',data=tips) #hue = sex,time,smoker

# %%
sns.relplot(x='total_bill',y='tip',hue = 'smoker',data=tips,style = 'time') #style = inform of shapes

# %%
sns.relplot(x='total_bill',y='tip',hue = 'size',data=tips) #hue #style for categorical

# %%
sns.relplot(x='total_bill',y='tip',hue = 'size',data=tips,palette = 'ch:r=-0.8,l=0.95') #hue interms of  golo color

# %%
sns.relplot(x='total_bill',y='tip',data = tips,size='size') #size = interms of golo katro hune

# %%
sns.relplot(x='total_bill',y='tip',data= tips,size='size',sizes = (50,100))

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500),value = randn(500).cumsum()))

# %%
sns.relplot(x='time',y='value',kind='line',data=df,sort=False)

# %%
df
# Out:
#      time     value
# 0       0 -0.654576
# 1       1 -0.556725
# 2       2 -1.937533
# 3       3 -1.389861
# 4       4  0.310649
# ..    ...       ...
# 495   495 -9.252941
# 496   496 -9.959959
# 497   497 -9.571314
# 498   498 -7.824829
# 499   499 -7.246562
#
# [500 rows x 2 columns]

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint',y='signal',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci = False) #confidence interval

# %%
sns.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci = 'sd')

# %%
sns.relplot(x='timepoint',y='signal',estimator = None,kind = 'line',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue = 'event',kind = 'line',data=fmri)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',hue='region',style='event',kind = 'line',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue='region',style = 'event',kind = 'line',data = fmri,markers = True,dashes = False)

# %%
sns.relplot(x='timepoint',y='signal',hue = 'region',units = 'subject',estimator = None,kind= 'line',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue = 'region',units = 'subject',estimator = None,kind= 'line',data=fmri.query("event=='stim'"))

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
dots = sns.load_dataset('dots')
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x='time',y='firing_rate',data = dots,kind= 'line',hue = 'coherence',style = 'choice')

# %%
palette = sns.cubehelix_palette(light = 0.8,n_colors = 6) #set colors

# %%
#change width  according with their intensities

# %%
sns.relplot(x='time',y='firing_rate',size ='coherence',style = 'choice',kind = 'line',data = dots,sizes = (1,5) )

# %%
sns.relplot(x='time',y='firing_rate',hue ='coherence', size ='coherence',style = 'choice',kind = 'line',data = dots,sizes = (1,5) )

# %%
#plotting date

# %%
df = pd.DataFrame(dict(time = pd.date_range('2019-06-02',periods = 500),value = randn(500).cumsum()))

# %%
df.head()
# Out:
#         time     value
# 0 2019-06-02  0.678687
# 1 2019-06-03  1.811690
# 2 2019-06-04  2.892579
# 3 2019-06-05  1.716805
# 4 2019-06-06  3.424141

# %%
g=sns.relplot(x='time',y='value',kind='line',data=df)
g.fig.autofmt_xdate()

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='time',data=tips) #col gen 2 graphs

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='size',data=tips)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',row='size',height = 3,data=tips)

# %%
sns.relplot(x='timepoint',y='signal',hue='subject',col='region',row='event',kind='line',data=fmri) #col is row

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='size',data=tips,col_wrap=3,height = 3) #height is size of graph

# %%
sns.lineplot( x='total_bill',y='tip',data=tips)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint',y='signal',style='event',hue='event',data=fmri,markers=True,ci=68,err_style='bars') #ci=none

# %%
sns.lineplot(x='timepoint',y='signal',style='event',hue='event',data=fmri.query("region == 'frontal'"),markers=True,ci=68,err_style='bars')

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.scatterplot(x='time',y='firing_rate',style='choice',data=dots)

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='species',y='petal_length',data=iris)

# %%
sns.relplot(x='species',y='petal_length',kind = 'line',data=iris.query("species =='virginica'"))

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['petal_length'])

# %% [markdown]
# # categorical data plotting

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#catplot #boxplot #stripplot #swarmplot etc

# %%
#catplot()

# %%
sns.catplot(x='day',y='total_bill',data=tips)

# %%
sns.catplot(x='day',y='total_bill',data=tips,jitter = False)

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind= 'swarm',hue = 'sex')

# %%
sns.catplot(x='smoker',y='tip',data=tips,order = ['No','Yes'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#boxplot 3 quartile values min

# %%
sns.catplot(x='day',y='total_bill',kind = 'box',data=tips,hue= 'sex')

# %%
sns.catplot(x='day',y='total_bill',kind = 'box',data=tips,hue= 'sex',dodge= False)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(x='color',y='price',kind = 'boxen',data=diamonds)

# %%
c= diamonds.sort_values('color')
c
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 7817    1.00  Very Good     D     SI2   63.5   59.0   4295  6.35  6.32  4.02
# 7816    1.00       Good     D     SI2   57.8   58.0   4295  6.61  6.55  3.80
# 7815    1.00  Very Good     D     SI2   61.5   63.0   4295  6.32  6.27  3.87
# 7809    0.56      Ideal     D      IF   61.9   57.0   4293  5.28  5.31  3.28
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 4861    1.00    Premium     J     SI1   60.8   58.0   3712  6.39  6.44  3.90
# 18421   1.52      Ideal     J     SI1   61.9   57.0   7491  7.37  7.33  4.55
# 18423   1.50  Very Good     J     VS2   62.6   58.0   7492  7.25  7.29  4.55
# 42108   0.65      Ideal     J     SI1   61.4   55.0   1276  5.58  5.62  3.44
# 14123   1.30      Ideal     J     SI1   61.5   55.0   5728  7.03  7.06  4.33
#
# [53940 rows x 10 columns]

# %%
sns.catplot(x='color',y='price',kind = 'boxen',data=c)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day',y='total_bill',kind='boxen',data=tips,dodge=False)

# %%
sns.catplot(x='total_bill',y='day',hue='time',kind = 'violin',data=tips)

# %%
sns.catplot(x='total_bill',y='day',hue='time',kind = 'violin',data=tips,split = True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex',y='survived',hue = 'class',kind='bar',data = titanic) #line - length of uncertaincity

# %%
sns.catplot(x='deck',kind='count',palette='ch:0.95',data = titanic,hue='class')

# %%
#point plot

# %%
sns.catplot(x='sex',y='survived',hue='class',kind='point',data=titanic)

# %%
#visualization
#distplot() #kdeplot() #jointplot() #rugplot()

# %%
#distplot( -histogram)

# %%
x=randn(100)

# %%
sns.distplot(x)

# %% [raw]
# #reference  -- https://www.youtube.com/watch?v=GcXcSZ0gQps  start from 2:00:00
